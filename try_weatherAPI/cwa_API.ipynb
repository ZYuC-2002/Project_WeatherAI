# %%
import requests

# %%
authorization = "CWA-FADE6AC3-54FB-452F-BC9D-2A94204257D6"
url = "https://opendata.cwa.gov.tw/api/v1/rest/datastore/O-A0001-001"
res = requests.get(url, {"Authorization": authorization})
resJson = res.json()
print(resJson)
# Out:
# {'success': 'true', 'result': {'resource_id': 'O-A0001-001', 'fields': [{'id': 'StationName', 'type': 'String'}, {'id': 'StationId', 'type': 'String'}, {'id': 'CoordinateName', 'type': 'String'}, {'id': 'CoordinateFormat', 'type': 'String'}, {'id': 'IntScaleValue', 'type': 'Float'}, {'id': 'IntScaleValue', 'type': 'Float'}, {'id': 'StationAltitude', 'type': 'String'}, {'id': 'CountyName', 'type': 'String'}, {'id': 'TownName', 'type': 'String'}, {'id': 'CountyCode', 'type': 'String'}, {'id': 'TownCode', 'type': 'String'}, {'id': 'Weather', 'type': 'String'}, {'id': 'Precipitation', 'type': 'Float'}, {'id': 'WindDirection', 'type': 'Float'}, {'id': 'WindSpeed', 'type': 'Float'}, {'id': 'AirTemperature', 'type': 'Float'}, {'id': 'RelativeHumidity', 'type': 'Integer'}, {'id': 'AirPressure', 'type': 'Float'}, {'id': 'UVIndex', 'type': 'Float'}, {'id': 'PeakGustSpeed', 'type': 'Float'}, {'id': 'DateTime', 'type': 'DateTime'}]}, 'records': {'Station': [{'StationName': '鼻頭', 'StationId': 'C0
# ...

# %%
Station = resJson["records"]["Station"]

for StationName in Station:
    print(StationName["StationName"])  # 印出所有測站名稱
# Out:
# 鼻頭
# 興海
# 後壁湖
# 山海
# 竹坑
# 加祿堂
# 鯤鯓國小
# 下寮
# 塭仔
# 汕尾
# 鳳鼻頭
# 蚵仔寮
# 南寮
# 文安
# 興達
# 城西
# 四草
# 蘆竹溝
# 蚵寮
# 前鎮
# 澳底
# 七美
# 望安
# 湖西
# 北竿
# 科教館
# 大溪漁港
# 石城
# 大武崙
# 野柳
# 淡水觀海
# 竹圍
# 中大臨海站
# 石門
# 觀音工業區
# 海天一線
# 香山濕地
# 水湳洞
# 八斗子
# 外湖
# 海埔
# 通霄漁港
# 松柏
# 溫寮
# 龍鳳
# 淡江大學蘭陽校園
# 林邊
# 六塊厝
# 田寮
# 新興坑尾
# 蘇澳
# 壯圍
# 北關
# 防潮門
# 臺中電廠
# 福寶
# 三豐
# 箔子寮
# 好美里
# 板橋
# 水試所成功
# 茂林蝶谷
# 東莒
# 西嶼
# 花嶼
# 金沙
# 金寧
# 烏坵
# 松山
# 高鐵苗栗
# 高鐵雲林
# 國一五楊N44K
# 基隆嶼
# 蘭嶼高中
# 蘭嶼燈塔
# 白沙灣
# 小林
# 大溪永福
# 玉蘭
# 五結
# 太平山
# 南山
# 雙連埤
# 頭城
# 大礁溪
# 三星
# 內城
# 冬山
# 礁溪
# 龜山島
# 三貂角
# 羅東
# 鶯子嶺
# 大福
# 坪林石牌
# 天祥
# 東華
# 鯉魚潭
# 水源
# 鳳林山
# 光復
# 西林
# 月眉山
# 大坑
# 加路蘭山
# 水璉
# 豐濱
# 明里
# 玉里
# 舞鶴
# 佳心
# 富源
# 吉安光華
# 鳳林
# 卓溪
# 新城
# 富世
# 萬榮
# 瑞穗
# 瑞穗林道
# 蕃薯寮
# 德武
# 赤柯山
# 東里
# 清水斷崖
# 清水林道
# 安通山
# 靜浦
# 長濱
# 東河
# 綠島
# 下馬
# 向陽
# 紅石
# 池上
# 鹿野
# 關山
# 土阪
# 大溪山
# 南田
# 金崙
# 太麻里
# 知本
# 富里
# 中壢
# 柳營
# 關西
# 新美
# 永靖
# 竹塘
# 雲林東勢
# 車城
# 大漢山
# 枋山
# 枋寮
# 楓港
# 檳榔
# 牡丹
# 佳樂水
# 墾丁
# 旭海
# 貓鼻頭
# 墾雷
# 四林格山
# 大坪頂
# 龍磐
# 獅子
# 東澳
# 南澳
# 和中
# 翠峰湖
# 和平林道
# 和平
# 樟樹山
# 桃源谷
# 西帽山
# 西德山
# 福山植物園
# ...

# %% [markdown]
# **各縣市之測站**
# - 新北: 新北466881 (自2023/01/03上午11時，原為板橋(466880))
# - 臺北: 臺北466920
# - 基隆: 基隆466940
# - 桃園: 桃園C0C480 (自2008/01/01，原為C1C480)
# - 新竹縣: 新竹467571
# - 新竹市: 新竹市東區C0D660
# - 苗栗: 苗栗C0E750
# - 臺中: 台中467490
# - 彰化: 員林C0G650 (相較之下比較老的)
# - 南投: 南投C0I460
# - 雲林: 虎尾C0K330 (相較之下比較老的)
# - 嘉義縣: 菜瓜坪C1M400 (相較之下比較老且海拔高度較接近平地的)
# - 嘉義市: 嘉義467480
# - 臺南: 臺南467410
# - 高雄: 高雄467441
# - 屏東: 屏東C0R170
# - 宜蘭: 宜蘭467080
# - 花蓮: 花蓮466990
# - 臺東: 臺東467660
# - 馬祖: 馬祖467990
# - 澎湖: 澎湖467350
# - 金門: 金門467110
# - 綠島: 綠島C0S730
# - 蘭嶼: 蘭嶼467620

# %% [markdown]
# ### json example

# %% [markdown]
# ``` json
# {
#   "success": "true",
#   "result": {
#     "resource_id": "O-A0001-001",
#     "fields": [
#       {
#         "id": "StationName",
#         "type": "String"
#       },
#       {
#         "id": "StationId",
#         "type": "String"
#       },
#       {
#         "id": "CoordinateName",
#         "type": "String"
#       },
#       {
#         "id": "CoordinateFormat",
#         "type": "String"
#       },
#       {
#         "id": "IntScaleValue",
#         "type": "Float"
#       },
#       {
#         "id": "IntScaleValue",
#         "type": "Float"
#       },
#       {
#         "id": "StationAltitude",
#         "type": "String"
#       },
#       {
#         "id": "CountyName",
#         "type": "String"
#       },
#       {
#         "id": "TownName",
#         "type": "String"
#       },
#       {
#         "id": "CountyCode",
#         "type": "String"
#       },
#       {
#         "id": "TownCode",
#         "type": "String"
#       },
#       {
#         "id": "Weather",
#         "type": "String"
#       },
#       {
#         "id": "Precipitation",
#         "type": "Float"
#       },
#       {
#         "id": "WindDirection",
#         "type": "Float"
#       },
#       {
#         "id": "WindSpeed",
#         "type": "Float"
#       },
#       {
#         "id": "AirTemperature",
#         "type": "Float"
#       },
#       {
#         "id": "RelativeHumidity",
#         "type": "Integer"
#       },
#       {
#         "id": "AirPressure",
#         "type": "Float"
#       },
#       {
#         "id": "UVIndex",
#         "type": "Float"
#       },
#       {
#         "id": "PeakGustSpeed",
#         "type": "Float"
#       },
#       {
#         "id": "DateTime",
#         "type": "DateTime"
#       }
#     ]
#   },
#   "records": {
#     "Station": [
#       {
#         "StationName": "鼻頭",
#         "StationId": "C0R860",
#         "ObsTime": {
#           "DateTime": "2024-01-21T14:00:00+08:00"
#         },
#         "GeoInfo": {
#           "Coordinates": [
#             {
#               "CoordinateName": "TWD67",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 22.106108,
#               "StationLongitude": 120.88986
#             },
#             {
#               "CoordinateName": "WGS84",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 22.1043,
#               "StationLongitude": 120.89788
#             }
#           ],
#           "StationAltitude": "31.0",
#           "CountyName": "屏東縣",
#           "TownName": "滿州鄉",
#           "CountyCode": "10013",
#           "TownCode": "10013240"
#         },
#         "WeatherElement": {
#           "Weather": "陰",
#           "Now": {
#             "Precipitation": 0.5
#           },
#           "WindDirection": 20,
#           "WindSpeed": 12,
#           "AirTemperature": 21.1,
#           "RelativeHumidity": 80,
#           "AirPressure": 1014.9,
#           "GustInfo": {
#             "PeakGustSpeed": -99,
#             "Occurred_at": {
#               "WindDirection": -99,
#               "DateTime": "-99"
#             }
#           },
#           "DailyExtreme": {
#             "DailyHigh": {
#               "TemperatureInfo": {
#                 "AirTemperature": 23.4,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T02:00:00+08:00"
#                 }
#               }
#             },
#             "DailyLow": {
#               "TemperatureInfo": {
#                 "AirTemperature": 20.8,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T08:30:00+08:00"
#                 }
#               }
#             }
#           }
#         }
#       },
#       {
#         "StationName": "興海",
#         "StationId": "C0R870",
#         "ObsTime": {
#           "DateTime": "2024-01-21T14:00:00+08:00"
#         },
#         "GeoInfo": {
#           "Coordinates": [
#             {
#               "CoordinateName": "TWD67",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 21.976986,
#               "StationLongitude": 120.83591
#             },
#             {
#               "CoordinateName": "WGS84",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 21.975178,
#               "StationLongitude": 120.84392
#             }
#           ],
#           "StationAltitude": "13.0",
#           "CountyName": "屏東縣",
#           "TownName": "滿州鄉",
#           "CountyCode": "10013",
#           "TownCode": "10013240"
#         },
#         "WeatherElement": {
#           "Weather": "陰",
#           "Now": {
#             "Precipitation": 17.5
#           },
#           "WindDirection": 61,
#           "WindSpeed": 7.3,
#           "AirTemperature": 20.8,
#           "RelativeHumidity": 80,
#           "AirPressure": 1016.8,
#           "GustInfo": {
#             "PeakGustSpeed": 14.9,
#             "Occurred_at": {
#               "WindDirection": 68,
#               "DateTime": "2024-01-21T13:50:00+08:00"
#             }
#           },
#           "DailyExtreme": {
#             "DailyHigh": {
#               "TemperatureInfo": {
#                 "AirTemperature": 23.4,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T02:10:00+08:00"
#                 }
#               }
#             },
#             "DailyLow": {
#               "TemperatureInfo": {
#                 "AirTemperature": 20.6,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T12:20:00+08:00"
#                 }
#               }
#             }
#           }
#         }
#       },
#       {
#         "StationName": "後壁湖",
#         "StationId": "C0R880",
#         "ObsTime": {
#           "DateTime": "2024-01-21T14:00:00+08:00"
#         },
#         "GeoInfo": {
#           "Coordinates": [
#             {
#               "CoordinateName": "TWD67",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 21.94747,
#               "StationLongitude": 120.73769
#             },
#             {
#               "CoordinateName": "WGS84",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 21.945665,
#               "StationLongitude": 120.745705
#             }
#           ],
#           "StationAltitude": "13.0",
#           "CountyName": "屏東縣",
#           "TownName": "恆春鎮",
#           "CountyCode": "10013",
#           "TownCode": "10013040"
#         },
#         "WeatherElement": {
#           "Weather": "多雲",
#           "Now": {
#             "Precipitation": 0
#           },
#           "WindDirection": 40,
#           "WindSpeed": 9.1,
#           "AirTemperature": 21.6,
#           "RelativeHumidity": 79,
#           "AirPressure": 1015,
#           "GustInfo": {
#             "PeakGustSpeed": 17.4,
#             "Occurred_at": {
#               "WindDirection": 58,
#               "DateTime": "2024-01-21T13:37:00+08:00"
#             }
#           },
#           "DailyExtreme": {
#             "DailyHigh": {
#               "TemperatureInfo": {
#                 "AirTemperature": 23.6,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T00:40:00+08:00"
#                 }
#               }
#             },
#             "DailyLow": {
#               "TemperatureInfo": {
#                 "AirTemperature": 21.1,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T06:30:00+08:00"
#                 }
#               }
#             }
#           }
#         }
#       },
#       {
#         "StationName": "山海",
#         "StationId": "C0R890",
#         "ObsTime": {
#           "DateTime": "2024-01-21T14:00:00+08:00"
#         },
#         "GeoInfo": {
#           "Coordinates": [
#             {
#               "CoordinateName": "TWD67",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 21.989578,
#               "StationLongitude": 120.7011
#             },
#             {
#               "CoordinateName": "WGS84",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 21.987778,
#               "StationLongitude": 120.70912
#             }
#           ],
#           "StationAltitude": "33.0",
#           "CountyName": "屏東縣",
#           "TownName": "恆春鎮",
#           "CountyCode": "10013",
#           "TownCode": "10013040"
#         },
#         "WeatherElement": {
#           "Weather": "多雲",
#           "Now": {
#             "Precipitation": 0
#           },
#           "WindDirection": 61,
#           "WindSpeed": 6.2,
#           "AirTemperature": 21.7,
#           "RelativeHumidity": 73,
#           "AirPressure": 1014.6,
#           "GustInfo": {
#             "PeakGustSpeed": 14,
#             "Occurred_at": {
#               "WindDirection": 64,
#               "DateTime": "2024-01-21T13:46:00+08:00"
#             }
#           },
#           "DailyExtreme": {
#             "DailyHigh": {
#               "TemperatureInfo": {
#                 "AirTemperature": 23,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T02:50:00+08:00"
#                 }
#               }
#             },
#             "DailyLow": {
#               "TemperatureInfo": {
#                 "AirTemperature": 21.5,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T06:20:00+08:00"
#                 }
#               }
#             }
#           }
#         }
#       },
#       {
#         "StationName": "竹坑",
#         "StationId": "C0R900",
#         "ObsTime": {
#           "DateTime": "2024-01-21T14:00:00+08:00"
#         },
#         "GeoInfo": {
#           "Coordinates": [
#             {
#               "CoordinateName": "TWD67",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 22.140247,
#               "StationLongitude": 120.69413
#             },
#             {
#               "CoordinateName": "WGS84",
#               "CoordinateFormat": "decimal degrees",
#               "StationLatitude": 22.13845,
#               "StationLongitude": 120.70215
#             }
#           ],
#           "StationAltitude": "30.0",
#           "CountyName": "屏東縣",
#           "TownName": "車城鄉",
#           "CountyCode": "10013",
#           "TownCode": "10013230"
#         },
#         "WeatherElement": {
#           "Weather": "多雲",
#           "Now": {
#             "Precipitation": 0
#           },
#           "WindDirection": 79,
#           "WindSpeed": 4.9,
#           "AirTemperature": 23.2,
#           "RelativeHumidity": 62,
#           "AirPressure": 1015,
#           "GustInfo": {
#             "PeakGustSpeed": 13.8,
#             "Occurred_at": {
#               "WindDirection": 85,
#               "DateTime": "2024-01-21T13:05:00+08:00"
#             }
#           },
#           "DailyExtreme": {
#             "DailyHigh": {
#               "TemperatureInfo": {
#                 "AirTemperature": 23.9,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T05:00:00+08:00"
#                 }
#               }
#             },
#             "DailyLow": {
#               "TemperatureInfo": {
#                 "AirTemperature": 21.9,
#                 "Occurred_at": {
#                   "DateTime": "2024-01-21T01:50:00+08:00"
#                 }
#               }
#             }
#           }
#         }
#       }
#     ]
#   }
# }
# ```
